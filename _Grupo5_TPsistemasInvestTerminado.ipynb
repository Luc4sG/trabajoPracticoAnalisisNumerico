# %% [markdown]
# # Grupo 5
#
# - Chanampa Jazmin
# - Dusset Maia
# - Gauna Lesteyme Lucas
# - Gonzalez Zago Joaquin

# %% [markdown]
# # Parte 1: Introducción a las Librerías

# %% [markdown]
# ## 1. NumPy: Operaciones con Matrices
# NumPy es una biblioteca fundamental en Python para el cálculo numérico y el procesamiento de grandes volúmenes de datos. Ofrece un conjunto de funciones y estructuras de datos optimizadas para operaciones matemáticas, principalmente a través de su estructura central: el array de NumPy (similar a las matrices en matemáticas). Los arrays de NumPy son altamente eficientes en términos de memoria y rendimiento, lo que permite realizar cálculos sobre grandes conjuntos de datos de forma rápida y con menor uso de recursos.
#
# Para multiplicar matrices utilizamos la funcion numpy.dot() o el operador @.

# %%
import numpy as np

A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])
C = np.dot(A, B)  # o C = A @ B
print(C)  # [[19 22] [43 50]]
# Out:
# [[19 22]
#  [43 50]]

# %% [markdown]
# ### Cálculo de la Inversa de una Matriz: Usamos numpy.linalg.inv() para obtener la inversa.

# %%
A = np.array([[1, 2], [3, 4]])
A_inv = np.linalg.inv(A)
print(A_inv)  # [[-2.   1. ] [ 1.5 -0.5]]
# Out:
# [[-2.   1. ]
#  [ 1.5 -0.5]]

# %% [markdown]
# ### Cálculo de Valores Propios y Vectores Propios: Utilizamos numpy.linalg.eig().

# %%
A = np.array([[4, -2], [1, 1]])
eigenvalues, eigenvectors = np.linalg.eig(A)
print("Valores propios:", eigenvalues)
print("Vectores propios:", eigenvectors)
# Out:
# Valores propios: [3. 2.]
# Vectores propios: [[0.89442719 0.70710678]
#  [0.4472136  0.70710678]]

# %% [markdown]
# ## 2. Resolver un Sistema de Ecuaciones Lineales
# Para resolver un sistema de ecuaciones lineales usando matrices en NumPy, primero debemos expresar el sistema en forma matricial. Un sistema de ecuaciones como:
#
# 2x + 3y = 8
#  x - 2y = -3
#
# se puede escribir en términos de matrices como:
# A * x = B
#
# donde:
# A es la matriz de coeficientes [[2, 3], [1, -2]]
# B es el vector de resultados [8, -3]
# Para resolver este sistema en NumPy, usamos numpy.linalg.solve(A, B), que devuelve la solución para 'X' y 'Y' sin necesidad de calcular la inversa de A.

# %%
import numpy as np

# Definimos la matriz de coeficientes A y el vector de resultados B
A = np.array([[2, 3], [1, -2]])
B = np.array([8, -3])

# Resolvemos el sistema de ecuaciones
solution = np.linalg.solve(A, B)

# Mostramos la solución para x y y
print("Solución:", solution)
# Out:
# Solución: [1. 2.]

# %% [markdown]
# ## 3. SymPy y Cálculo Diferencial
# SymPy es una biblioteca de Python dedicada al cálculo simbólico, que permite realizar operaciones matemáticas de forma analítica en lugar de numérica. A diferencia de otras bibliotecas como NumPy o SciPy, que se enfocan en cálculos numéricos, SymPy manipula expresiones matemáticas simbólicamente, tal como lo haría un matemático. Esto permite simplificar expresiones, derivar funciones, integrar y resolver ecuaciones diferenciales de manera exacta y sin aproximaciones.
#
# **En el ámbito del cálculo diferencial, SymPy es especialmente útil en áreas como:**
#
# **Derivación y Diferenciación Automática:** Permite calcular derivadas de expresiones simbólicas, simplificar resultados y manipular expresiones derivadas para análisis adicionales.
# Integración y Resolución de Integrales: SymPy permite resolver integrales indefinidas y definidas, simplificar expresiones integrales y calcular primitivas simbólicamente.
# Ecuaciones Diferenciales: SymPy es una herramienta poderosa para la resolución de ecuaciones diferenciales ordinarias (EDO) y parciales (EDP) de forma simbólica. A través de sus funciones, permite encontrar soluciones exactas cuando existen y explorar soluciones generales o particulares.
# SymPy en la Resolución de Ecuaciones Diferenciales
# La biblioteca SymPy incluye funciones específicas para resolver ecuaciones diferenciales, como dsolve(), que permite resolver EDOs, y herramientas para trabajar con EDPs. Al utilizar SymPy en lugar de métodos puramente numéricos, obtenemos ventajas significativas, como:
#
# **Soluciones Exactas:** SymPy permite obtener soluciones exactas (simbólicas), mientras que los métodos numéricos, como los métodos de Euler o Runge-Kutta, solo proporcionan aproximaciones.
# **Análisis Completo de la Solución:** Las soluciones simbólicas facilitan la comprensión de la estructura matemática de la respuesta, permitiendo simplificar, analizar y derivar nuevas relaciones.
# **Manipulación de Expresiones:** Con una solución simbólica, es posible manipular la expresión final para obtener derivadas, integrales adicionales u otras transformaciones sin pérdida de precisión.
# **Ejemplo de SymPy Resolviendo una Ecuación Diferencial**
# A continuación, se muestra un ejemplo de cómo SymPy puede resolver simbólicamente una ecuación diferencial ordinaria.

# %%
import sympy as sp

# Definimos la variable independiente y la función dependiente
t = sp.symbols('t')
y = sp.Function('y')(t)

# Definimos la ecuación diferencial: y' + y = e^t
equation = sp.Eq(y.diff(t) + y, sp.exp(t))

# Resolvemos la ecuación diferencial
solution = sp.dsolve(equation)

# Mostramos la solución
solution
# Out:
# Eq(y(t), C1*exp(-t) + exp(t)/2)

# %% [markdown]
# Este código define y resuelve la ecuación diferencial ordinaria **𝑦′+𝑦=𝑒𝑡** proporcionando la solución simbólica exacta. La capacidad de obtener esta solución analítica es una ventaja de SymPy frente a métodos que solo pueden aproximar soluciones numéricamente.

# %% [markdown]
# ## 4. SciPy: Resolución de Ecuaciones Diferenciales

# %% [markdown]
# SciPy es una biblioteca de Python construida sobre NumPy, diseñada para resolver problemas matemáticos, científicos y de ingeniería. Mientras que NumPy proporciona estructuras de datos rápidas y eficientes, SciPy amplía estas capacidades con una amplia gama de herramientas y algoritmos especializados, como integración, optimización, álgebra lineal avanzada y estadísticas. SciPy ofrece herramientas para resolver ecuaciones diferenciales de forma numérica, enfocándose en métodos eficientes y precisos. Dentro de SciPy, las funciones más utilizadas para resolver ecuaciones diferenciales son odeint y solve_ivp. Ambas se encuentran en el submódulo scipy.integrate y son especialmente útiles para resolver ecuaciones diferenciales ordinarias (EDOs). A continuación, se describen sus principales características y diferencias.
#
# **Función odeint**: odeint es una función ampliamente utilizada para resolver sistemas de ecuaciones diferenciales de primer orden.
# **Uso:** Requiere definir la función que describe el sistema de ecuaciones diferenciales y acepta parámetros adicionales que se pueden pasar a dicha función.
# **Ventaja:** odeint es sencilla y rápida para resolver problemas de ecuaciones diferenciales relativamente simples y bien comportados.
# **Limitación:** Dado que está basada en un código antiguo, puede ser menos flexible y menos compatible con sistemas complejos o configuraciones avanzadas de integración.

# %%
from scipy.integrate import odeint

# Definimos la función del sistema de ecuaciones
def modelo(y, t):
    dydt = -2 * y + 3
    return dydt

# Condición inicial y valores de tiempo
y0 = 5
t = np.linspace(0, 10, 100)

# Resolución del sistema con odeint
sol = odeint(modelo, y0, t)

# %% [markdown]
# **Función solve_ivp**
# **Descripción:** solve_ivp (solve initial value problem) es una función más moderna y flexible para resolver EDOs, que incluye varios métodos de integración (como Runge-Kutta de orden 5, RK45, y Radau).
# **Uso:** Similar a odeint, requiere definir la función del sistema, pero permite especificar el método de integración y el intervalo de solución.
# **Ventaja:** solve_ivp es más flexible y compatible con problemas más complejos, además de que admite varias opciones de métodos y configuraciones avanzadas.
# **Limitación:** Aunque ofrece múltiples métodos, puede requerir un ajuste cuidadoso de parámetros para obtener un rendimiento óptimo.

# %%
from scipy.integrate import solve_ivp

# Definimos la función del sistema de ecuaciones
def modelo(t, y):
    dydt = -2 * y + 3
    return dydt

# Condición inicial y resolución con solve_ivp
t_span = (0, 10)   # Intervalo de tiempo
y0 = [5]           # Condición inicial
sol = solve_ivp(modelo, t_span, y0, method='RK45')

# %% [markdown]
# **¿Cuándo usar odeint o solve_ivp?**
# odeint es una buena opción para problemas estándar o simples, donde se necesita un enfoque rápido y sin configuraciones avanzadas.
# solve_ivp es preferible en problemas complejos, donde se necesite control sobre el método de integración, o cuando se busque una solución en un rango específico con pasos de tiempo adaptativos.

# %% [markdown]
# ## 5. Graficar Campos Vectoriales con Matplotlib
#
# **Matplotlib** es una biblioteca de Python para la visualización de datos, permitiendo la creación de gráficos de líneas, histogramas, gráficos de dispersión y muchos otros tipos de visualización. Es ampliamente usada en ciencia de datos, análisis y visualización científica por su flexibilidad y facilidad de uso.
#
# **Graficar Campos Vectoriales con Matplotlib**
# Para graficar campos vectoriales en Matplotlib, se usa la función quiver, que permite representar un campo de vectores en un plano 2D. Un campo vectorial es una representación visual de vectores en diferentes puntos, que indican dirección y magnitud en una región del espacio.
#
# **Función quiver**
# La función quiver de Matplotlib se utiliza para trazar flechas en cada punto de un campo, representando vectores en coordenadas X e Y. La flecha apunta en la dirección del vector, y su tamaño representa la magnitud del vector.
#
# **Sintaxis Básica**
#
# import matplotlib.pyplot as plt
# import numpy as np
#
# plt.quiver(X, Y, U, V, kwargs)
#
# **Parámetros Principales**
# X, Y: Arrays de coordenadas donde se colocarán las colas de los vectores. Estos son arreglos de las coordenadas en el eje X y Y.
#
# U, V: Arrays de componentes vectoriales en las direcciones X e Y, respectivamente. Es decir, U y V definen la dirección y magnitud de cada vector en el campo.
#
# **Argumentos Opcionales (kwargs)**
#
# scale: Escala para los vectores. Permite ajustar la longitud de las flechas; si se omite, Matplotlib ajusta la escala automáticamente.
#
# scale_units: Unidades en las que se basa la escala (por ejemplo, "width" o "height").
#
# angles: Dirección de los vectores (por ejemplo, "xy" hace que las flechas apunten en la dirección (U, V)).
#
# color: Color de las flechas.
#
# width: Grosor de las flechas.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Definimos una cuadrícula de puntos en el espacio
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)
X, Y = np.meshgrid(x, y)

# Definimos los componentes del campo vectorial
U = -Y  # Componente en X
V = X   # Componente en Y

# Creamos el gráfico del campo vectorial
plt.quiver(X, Y, U, V, color='blue', scale=20)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Campo Vectorial usando quiver')
plt.grid()
plt.show()

# %% [markdown]
# # Parte 2: Aplicaciones Numéricas y Simbólicas

# %% [markdown]
# A continuacion se resolveremos la siguiente ecuacion diferencial: y'' + 9y = e^t, y(0) = 0, y'(0) = 0
#
# En el enfoque simbólico, utilizaremos la función dsolve de **SymPy** para obtener una solución exacta de la ecuación diferencial. Este enfoque es ideal cuando queremos una solución exacta y una comprensión clara de la forma matemática de la respuesta.

# %%
import sympy as sp

# Definimos las variables y la función
t = sp.symbols('t')
y = sp.Function('y')(t)

# Definimos la ecuación diferencial
eq = sp.Eq(y.diff(t, t) + 9 * y, sp.exp(t))

# Condiciones iniciales
ics = {y.subs(t, 0): 0, y.diff(t).subs(t, 0): 0}

# Resolución de la ecuación diferencial
solution_sym = sp.dsolve(eq, y, ics=ics)

# Mostrar la solución simbólica
solution_sym
# Out:
# Eq(y(t), exp(t)/10 - sin(3*t)/30 - cos(3*t)/10)

# %% [markdown]
# Para resolver esta ecuación diferencial de forma numérica, usaremos la función solve_ivp de **SciPy**. Aquí debemos expresar la ecuación diferencial como un sistema de primer orden para que sea compatible con los métodos numéricos de SciPy.

# %%
from scipy.integrate import solve_ivp
import numpy as np
import matplotlib.pyplot as plt

# Definimos el sistema de primer orden
def system(t, Y):
    y, dy = Y
    d2y = np.exp(t) - 9 * y
    return [dy, d2y]

# Condiciones iniciales
y0 = [0, 0]  # y(0) = 0, y'(0) = 0

# Intervalo de tiempo
t_span = (0, 5)
t_eval = np.linspace(0, 5, 100)

# Resolución numérica del sistema
solution_num = solve_ivp(system, t_span, y0, t_eval=t_eval)

# Graficar la solución numérica
plt.plot(solution_num.t, solution_num.y[0], label="y(t) - Solución Numérica")
plt.xlabel("t")
plt.ylabel("y(t)")
plt.title("Solución Numérica con SciPy")
plt.legend()
plt.show()

# %% [markdown]
# **Comparación de los Enfoques**
#
# **SymPy (Enfoque Simbólico):**
#
# Ventaja: Proporciona una solución exacta en términos matemáticos, útil para análisis teóricos y cuando queremos una representación algebraica de la respuesta.
# Desventaja: Puede ser ineficiente o imposible de resolver si la ecuación es demasiado compleja o no tiene una solución simbólica.
#
# **SciPy (Enfoque Numérico):**
#
# Ventaja: Es muy rápido y eficiente para ecuaciones diferenciales complejas o para sistemas de ecuaciones que no tienen solución exacta.
# Desventaja: La solución es aproximada y depende del intervalo de tiempo y el método de integración, por lo que no es ideal cuando se necesita una solución exacta.
#
# **Conclusiones**
# Se utiliza SymPy cuando se necesita una solución exacta y la ecuación es manejable de forma simbólica. En cambio, se puede optar por SciPy en casos donde la ecuación es compleja, el sistema tiene muchas variables, o se necesita una solución rápida y aproximada en un intervalo específico de tiempo.

# %% [markdown]
# ## 2. Transformada de Laplace en SymPy
# La biblioteca SymPy permite calcular la Transformada de Laplace y su inversa de forma simbólica, lo cual es útil para trabajar con ecuaciones diferenciales y sistemas dinámicos.
#
# #### Uso de las funciones laplace_transform e inverse_laplace_transform en SymPy laplace_transform ####
#
# #### Laplace_Transform ####
# La función **laplace_transform** en SymPy calcula la Transformada de Laplace de una función en el dominio del tiempo.
#
# **Sintaxis:**
# **laplace_transform(f, t, s)**
#
# **Parámetros:**
#
# f: la función a transformar, expresada en términos de '𝑡' (tiempo).
#
# t: la variable del dominio del tiempo (generalmente, 𝑡).
#
# s: la variable del dominio de la frecuencia (generalmente, 𝑠).
#
# Retorno: Devuelve una tupla con tres elementos: la transformada de Laplace de la función, la región de convergencia y una condición para la variable 𝑠.
#
# En el siguiente ejemplo, la función sp.laplace_transform() calcula la Transformada de Laplace de **𝑒^−2𝑡**, transformando la función al dominio 𝑠.

# %%
import sympy as sp

# Definimos la variable y la función
t, s = sp.symbols('t s')
f = sp.exp(-2 * t)

# Calculamos la Transformada de Laplace
laplace_f = sp.laplace_transform(f, t, s)
laplace_f
# Out:
# (1/(s + 2), -2, True)

# %% [markdown]
# #### inverse_laplace_transform ####
#
# La función inverse_laplace_transform calcula la Transformada de Laplace inversa, devolviendo la función en el dominio del tiempo.
#
# **Sintaxis:
# inverse_laplace_transform(F, s, t)**
#
# Parámetros:
#
# F: la función en el dominio de la frecuencia (en términos de 𝑠) a transformar de vuelta al dominio del tiempo.
# s: la variable del dominio de la frecuencia.
# t: la variable del dominio del tiempo.
# Retorno: Devuelve la función en el dominio del tiempo correspondiente a la Transformada de Laplace inversa.
#
# Ejemplo:

# %%
# Definimos la función en el dominio de la frecuencia
F = 1 / (s + 2)

# Calculamos la Transformada de Laplace inversa
inverse_laplace_f = sp.inverse_laplace_transform(F, s, t)
inverse_laplace_f
# Out:
# exp(-2*t)*Heaviside(t)

# %% [markdown]
# #### Conclusiones ####
#
# **La Transformada de Laplace es especialmente útil en áreas como:**
#
# **Resolución de Ecuaciones Diferenciales:** Es una herramienta clave para resolver ecuaciones diferenciales lineales con condiciones iniciales. Al transformar la ecuación diferencial en una ecuación algebraica en el dominio de 𝑠, el problema se simplifica considerablemente.
#
# **Análisis de Sistemas de Control:** En ingeniería de control, la Transformada de Laplace permite analizar sistemas de control lineales. Facilita el diseño y estudio de la estabilidad y respuesta en el tiempo de sistemas de control.
#
# **Procesamiento de Señales:** Permite analizar y manipular señales en el dominio de la frecuencia, siendo fundamental en telecomunicaciones y electrónica para estudiar el comportamiento de filtros y sistemas de transmisión.
#
# **Física e Ingeniería Eléctrica:** Se usa en circuitos eléctricos y sistemas dinámicos para modelar y resolver problemas que involucran elementos como resistencias, capacitores e inductores.
#
# La capacidad de SymPy para realizar tanto la Transformada de Laplace como su inversa de manera simbólica permite un análisis teórico y exacto de estos sistemas, lo cual es especialmente útil en contextos académicos, investigación y en la primera fase de diseño de sistemas antes de realizar simulaciones numéricas más complejas.

# %% [markdown]
# ## 3. Construcción y Manipulación de Matrices Simbólicas en SymPy
# En SymPy, puedes crear matrices simbólicas usando la clase Matrix. Esto es útil cuando quieres trabajar con variables en lugar de números específicos.
#
# Para construir matrices simbólicas en SymPy, se utilizan las clases Matrix o MutableMatrix, que permiten definir matrices con entradas simbólicas. Primero, es necesario definir las variables simbólicas y luego crear la matriz especificando sus elementos.
#
# Ejemplo Básico:
# Aquí creamos una matriz simbólica 𝐴 con elementos que son variables simbólicas:

# %%
import sympy as sp

# Definimos variables simbólicas
a, b, c, d = sp.symbols('a b c d')

# Creamos una matriz simbolica 'A' con entradas a, b, c y d.
A = sp.Matrix([[a, b], [c, d]])

# Mostramos la matriz
A
# Out:
# Matrix([
# [a, b],
# [c, d]])

# %% [markdown]
# #### Ejemplo de Matrices Simbólicas en Sistemas de Ecuaciones ####
# Las matrices simbólicas son útiles para resolver sistemas de ecuaciones lineales de manera simbólica. Por ejemplo, para el sistema de ecuaciones:
#
# a*x + b*y = 1
# c*x + d*y = 0
#
# Podemos representar el sistema como una ecuación matricial A * X = B, donde:
#
# A = Matrix([[a, b], [c, d]])
# X = Matrix([x, y])
# B = Matrix([1, 0])
#
# Podemos resolver el sistema con SymPy de esta manera:

# %%
# Definimos las variables simbólicas para las incógnitas
x, y = sp.symbols('x y')

# Definimos la matriz de coeficientes A y el vector de resultados B
A = sp.Matrix([[a, b], [c, d]])
B = sp.Matrix([1, 0])

# Calculamos la solución del sistema A * X = B
solution = A.solve_least_squares(B)

# Mostramos la solución para x y y
solution
# Out:
# Matrix([
# [(-(b*conjugate(a) + d*conjugate(c))*(conjugate(b) - (a*conjugate(b) + c*conjugate(d))*conjugate(a)/(a*conjugate(a) + c*conjugate(c)))*conjugate(1/sqrt(a*conjugate(a) + c*conjugate(c)))/(sqrt(b*conjugate(b) + d*conjugate(d) - (a*conjugate(b) + c*conjugate(d))*(b*conjugate(a) + d*conjugate(c))*conjugate(1/sqrt(a*conjugate(a) + c*conjugate(c)))/sqrt(a*conjugate(a) + c*conjugate(c)))*conjugate(sqrt(b*conjugate(b) + d*conjugate(d) - (a*conjugate(b) + c*conjugate(d))*(b*conjugate(a) + d*conjugate(c))*conjugate(1/sqrt(a*conjugate(a) + c*conjugate(c)))/sqrt(a*conjugate(a) + c*conjugate(c))))) + conjugate(a)/sqrt(a*conjugate(a) + c*conjugate(c)))/conjugate(sqrt(a*conjugate(a) + c*conjugate(c)))],
# ...

# %% [markdown]
# ## 4. Cálculo del Determinante y la Inversa de una Matriz Simbólica
# En SymPy, podemos calcular el determinante y la inversa de una matriz simbólica usando los métodos .det() y .inv().
#
# Ejemplo practico:

# %%
# Cálculo del determinante
det_A = A.det()
print("Determinante de A:", det_A)

# Cálculo de la inversa
inv_A = A.inv()
print("Inversa de A:", inv_A)
# Out:
# Determinante de A: a*d - b*c
# Inversa de A: Matrix([[d/(a*d - b*c), -b/(a*d - b*c)], [-c/(a*d - b*c), a/(a*d - b*c)]])

# %% [markdown]
# ## 5. Ventajas de SymPy sobre NumPy para Matrices Simbólicas
# SymPy y NumPy tienen enfoques diferentes al trabajar con matrices:
#
# Aunque con ambas se puede trabajar con matrices, ofrecen capacidades y enfoques diferentes cuando se trata de matrices simbólicas.
#
# **Cálculo simbólico:** SymPy está diseñada para el cálculo simbólico, permitiendo trabajar con variables y realizar manipulaciones algebraicas en lugar de valores numéricos concretos. Esto es fundamental en problemas donde las entradas de la matriz son expresiones simbólicas (como variables, constantes algebraicas, o funciones). NumPy, en cambio, está enfocado en cálculos numéricos y no tiene soporte nativo para operaciones simbólicas.
#
# **Manipulación y simplificación algebraica:** SymPy permite simplificar expresiones, expandir polinomios, factorizar, y reordenar términos en las entradas de la matriz. Esto es especialmente útil para obtener soluciones en su forma más simple o para reformular ecuaciones de sistemas lineales. NumPy no tiene capacidades para manipulación algebraica.
#
# **Operaciones avanzadas con matrices simbólicas:** Con SymPy, se pueden calcular derivadas, integrales y límites directamente sobre las entradas simbólicas de una matriz. Esto es útil para problemas de optimización simbólica, análisis de sensibilidad, y en contextos matemáticos avanzados, como álgebra y cálculo multivariable. NumPy, al ser numérica, no permite estas operaciones sin la ayuda de otras librerías.
#
# **Solución de sistemas lineales simbólicos:** SymPy permite resolver sistemas de ecuaciones lineales donde tanto los coeficientes como las soluciones son simbólicas. NumPy puede resolver sistemas lineales, pero solo con coeficientes numéricos.
#
# **Resultados exactos:** SymPy trabaja con aritmética exacta, proporcionando resultados en fracciones y expresiones algebraicas exactas en lugar de valores aproximados, lo cual es ideal en contextos donde la precisión simbólica es importante. NumPy, al ser numérica, siempre devuelve valores aproximados (en punto flotante), que pueden ser propensos a errores de redondeo.
#
# **Conclusiones**
# SymPy es ideal cuando se necesita manipular matrices de manera simbólica, realizar operaciones algebraicas, y obtener resultados en términos exactos, mientras que NumPy es excelente para operaciones numéricas rápidas y eficientes, pero carece de soporte para manipulación simbólica y algebraica.

# %% [markdown]
# # Parte 3: Cálculo de Derivadas, limites e integrales

# %% [markdown]
# ## 1. Cálculo de Derivadas Simbólicas en SymPy
# La biblioteca SymPy permite calcular derivadas simbólicas usando la función diff, tanto para derivadas simples como parciales.
#
# #### Derivadas Simples con diff ####
# Para calcular una derivada simple, define la función en términos de una variable y aplica diff con respecto a esa variable.
#
# Ejemplo: Derivada Simple
#
# Calcula la derivada de f(x) = x^3 + 2x^2 + x con respecto a x:

# %%
import sympy as sp

# Definimos la variable y la función
x = sp.symbols('x')
f = x**3 + 2*x**2 + x

# Calculamos la derivada de f con respecto a x
f_prime = sp.diff(f, x)
f_prime
# Out:
# 3*x**2 + 4*x + 1

# %% [markdown]
# #### Derivadas Parciales con diff ####
# Para derivadas parciales, define la función en términos de varias variables y aplica diff con respecto a la variable que deseas derivar.
#
# Ejemplo: Derivada Parcial
#
# Calcula la derivada parcial de g(x, y) = x^2 * y + y^2 * x con respecto a x y luego con respecto a y:

# %%
# Definimos las variables y la función
x, y = sp.symbols('x y')
g = x**2 * y + y**2 * x

# Derivada parcial de g con respecto a x
g_x = sp.diff(g, x)

# Derivada parcial de g con respecto a y
g_y = sp.diff(g, y)

g_x, g_y
# Out:
# (2*x*y + y**2, x**2 + 2*x*y)

# %% [markdown]
# ## 2. Cálculo de Límites Simbólicos en SymPy
# En SymPy, se pueden calcular límites simbólicos de funciones usando la función limit. Esta función es muy útil para calcular límites de manera exacta sin realizar aproximaciones numéricas.
#
# **Uso de la Función limit**
# La función limit toma tres argumentos principales:
#
# func: la función de la que deseas calcular el límite.
#
# var: la variable que tiende a un valor.
#
# value: el valor al que se acerca la variable.
#
# **Sintaxis: limit(func, var, value)**
#
# SymPy también permite calcular límites laterales usando los argumentos opcionales dir, donde:
#
# dir='+' calcula el límite cuando la variable tiende al valor desde la derecha (límite por la derecha).
#
# dir='-' calcula el límite cuando la variable tiende al valor desde la izquierda (límite por la izquierda).
#
# **Ejemplo: Cálculo de un Límite**
# Calculemos el límite de la función f(x) = (x**2 - 1) / (x - 1) cuando x tiende a 1.

# %%
import sympy as sp

# Definimos la variable y la función
x = sp.symbols('x')
f = (x**2 - 1) / (x - 1)

# Calculamos el límite cuando x tiende a 1
limite = sp.limit(f, x, 1)
limite
# Out:
# 2

# %% [markdown]
# **Ejemplo de Límite Lateral con argumento opcional dir**
#
# Calculemos el límite de 1 / x cuando x tiende a 0 desde la derecha (dir='+').

# %%
# Calculamos el límite cuando x tiende a 0 por la derecha
limite_derecha = sp.limit(1 / x, x, 0, dir='+')
limite_derecha
# Out:
# oo

# %% [markdown]
# ## 3. Ventajas de SymPy sobre forma tradicional##
#
# El cálculo simbólico de límites con SymPy ofrece varias ventajas sobre el cálculo manual, especialmente en problemas complejos. A continuación se detallan algunas de estas ventajas y cómo SymPy maneja el cálculo simbólico de límites complicados:
#
# #### Ventajas del Cálculo Simbólico de Límites con SymPy ####
# **Rapidez y Eficiencia:** Calcular límites simbólicamente en SymPy es mucho más rápido que hacerlo a mano, especialmente cuando se trata de expresiones largas o complejas. SymPy aplica algoritmos optimizados para simplificar expresiones y encontrar límites de manera eficiente, ahorrando tiempo y esfuerzo.
#
# **Reducción de Errores:** El cálculo manual de límites, especialmente en expresiones complejas o con límites laterales, puede ser propenso a errores. SymPy sigue reglas algebraicas de manera estricta y minimiza la posibilidad de errores en los pasos intermedios.
#
# **Capacidad para Resolver Límites Complicados:** SymPy es capaz de manejar límites complicados que involucran funciones trascendentales (como exponenciales, logaritmos y funciones trigonométricas), infinitos, indeterminaciones y límites en el infinito. Para problemas que requieren simplificaciones avanzadas o técnicas de análisis asintótico, SymPy puede obtener la solución exacta de forma directa, algo que manualmente sería laborioso o difícil de manejar.
#
# **Límites Laterales:** Con SymPy, es fácil calcular límites laterales especificando la dirección (dir='+' o dir='-'). Esta característica es útil cuando queremos estudiar el comportamiento de una función en un punto de discontinuidad o en situaciones de indeterminación. Calcular estos límites lateralmente a mano suele ser engorroso.
#
# **Automatización para Análisis Complejos:** SymPy permite calcular múltiples límites y realizar análisis más amplios en poco tiempo. En investigaciones y aplicaciones donde es necesario calcular varios límites en diferentes puntos, SymPy automatiza el proceso y facilita la comparación de resultados.
#
# #### Cómo Maneja SymPy el Cálculo de Límites Complicados ####
# SymPy utiliza algoritmos avanzados de álgebra simbólica y técnicas de simplificación para resolver límites. Por ejemplo, aplica reglas de factorización, simplificación de fracciones, y el uso de series de Taylor cuando es necesario. También reconoce patrones comunes de indeterminación (como 0/0 o ∞/∞) y utiliza técnicas apropiadas para cada caso, como la regla de L'Hôpital, aunque de forma automática y sin intervención del usuario.
#
# Para límites en puntos de discontinuidad o en infinito, SymPy ajusta su método según las características de la función, asegurando así una solución exacta. Esto es particularmente valioso en límites complejos donde el análisis manual podría ser extenso y desafiante.
#
# #### Conclusión ####
# SymPy facilita el cálculo simbólico de límites, ofreciendo rapidez, precisión y capacidad para manejar expresiones complejas que serían difíciles de resolver manualmente. Para estudiantes y profesionales, esto es una herramienta invaluable en el análisis matemático y en aplicaciones de cálculo avanzado, eliminando el riesgo de errores y permitiendo enfocarse en la interpretación y aplicación de los resultados.

# %% [markdown]
# ## 4. Importancia enfoque simbolico ##
#
# Un caso en el que el cálculo simbólico de límites es más útil que la evaluación numérica es cuando se enfrenta a una indeterminación, como 0/0 o ∞/∞. Estas indeterminaciones aparecen con frecuencia en matemáticas y física, especialmente al analizar comportamientos de funciones cerca de puntos críticos o en el infinito.
#
# #### Ejemplo: Funciones con Indeterminación ####
# Consideremos la función f(x) = (sin(x) / x) cuando x tiende a 0. Si intentamos evaluar esta función numéricamente en x = 0, obtenemos una indeterminación 0/0. Un enfoque numérico (como sustituir un valor muy cercano a cero) no da una respuesta precisa y puede resultar en valores muy diferentes, lo cual no garantiza la exactitud de la solución.
#
# En este caso, el enfoque simbólico es necesario porque:
#
# **El Cálculo Simbólico Permite Simplificar Expresiones Algebraicas:** SymPy, al calcular simbólicamente el límite, puede reconocer y simplificar la expresión sin(x) / x usando identidades trigonométricas. Al hacerlo, encuentra que el límite de sin(x) / x cuando x tiende a 0 es exactamente 1, una solución que el cálculo numérico no puede encontrar con precisión debido a la indeterminación.
#
# **Generalización de Resultados:** El enfoque simbólico da una expresión exacta del límite, que es útil en teoría matemática y en demostraciones. Por ejemplo, en cálculo, el límite de sin(x) / x en 0 es fundamental en series de Taylor y en análisis de funciones periódicas. Obtener el límite simbólico permite usar el resultado en contextos teóricos sin depender de aproximaciones.
#
# **Ejemplo con SymPy:**
# El siguiente cálculo devuelve 1, que es el valor exacto del límite de la función sin(x) / x en x = 0.

# %%
import sympy as sp

# Definimos la variable y la función
x = sp.symbols('x')
f = sp.sin(x) / x

# Calculamos el límite cuando x tiende a 0
limite = sp.limit(f, x, 0)
limite
# Out:
# 1

# %% [markdown]
# #### Razón por la que el Enfoque Simbólico es Necesario ####
# El cálculo simbólico es esencial en este tipo de problemas porque:
#
# **Evita Errores de Aproximación:** Los métodos numéricos pueden dar resultados inexactos o incluso divergentes al evaluar puntos cercanos a 0 en casos de indeterminación.
#
# **Garantiza la Exactitud en el Análisis Matemático:** En situaciones donde el comportamiento de la función en puntos críticos afecta el resultado general (como en optimización o análisis de límites en física), el enfoque simbólico asegura precisión y consistencia.

# %% [markdown]
# ##  4. Funcion 'Integrate'.
# La función integrate en SymPy permite calcular tanto integrales indefinidas como integrales definidas de forma simbólica.
#
# #### Integrales Indefinidas ####
#
# **Sintaxis para Integral Indefinida: integrate(func, var)**
#
# func: La función que queremos integrar.
#
# var: La variable respecto a la cual integramos.
#
# **Ejemplo: Calculemos la integral indefinida de f(x) = x^2 + 3x + 2 respecto a x**

# %%
import sympy as sp

# Definimos la variable y la función
x = sp.symbols('x')
f = x**2 + 3*x + 2

# Calculamos la integral indefinida de f respecto a x
integral_indefinida = sp.integrate(f, x)
integral_indefinida
# Out:
# x**3/3 + 3*x**2/2 + 2*x

# %% [markdown]
# #### Integrales Definidas ####
#
# **Sintaxis para Integral Definida: integrate(func, (var, a, b))**
#
# var: La variable respecto a la cual integramos.
#
# a y b: Los límites inferior y superior de integración, respectivamente.
#
# **Ejemplo: Calculemos la integral definida de g(x) = x^2 desde x = 0 hasta x = 2.**

# %%
# Definimos la función
g = x**2

# Calculamos la integral definida de g desde 0 hasta 2
integral_definida = sp.integrate(g, (x, 0, 2))
integral_definida
# Out:
# 8/3

# %% [markdown]
# # Parte 4: Exploracion Avanzada #

# %% [markdown]
# ##  1. Ec Diferenciales con ScyPy utilizando solve_ivp ##

# %% [markdown]
# En SciPy, la función **solve_ivp (solve initial value problem)** del módulo scipy.integrate es utilizada para resolver sistemas de ecuaciones diferenciales, incluidos aquellos que están acoplados. solve_ivp facilita la resolución de estos sistemas permitiendo obtener soluciones numéricas precisas en un intervalo de tiempo definido.
#
# **Pasos Clave para Resolver Sistemas Acoplados de Ecuaciones Diferenciales con solve_ivp**
#
# Definir el Sistema de Ecuaciones:
# Representamos el sistema de ecuaciones diferenciales acopladas como una función que devuelve las derivadas de cada variable dependiente con respecto a la variable independiente, usualmente el tiempo t.
#
# Especificar Condiciones Iniciales:
# Definimos un vector con las condiciones iniciales de cada variable dependiente. Esto permite a solve_ivp comenzar la integración desde un punto específico en el tiempo.
#
# Configurar el Intervalo de Integración:
# Definimos el rango de valores para la variable independiente (por ejemplo, tiempo) sobre el cual se resolverán las ecuaciones.
#
# Elegir un Método de Integración (opcional):
# solve_ivp permite seleccionar métodos específicos de integración (como RK45 o Radau). Por defecto, utiliza RK45, un método de Runge-Kutta de orden 5.
#
# **Ejemplo:Consideremos el siguiente sistema de ecuaciones acopladas:**
#
# dy1/dt = y2
#
# dy2/dt = -y1
#
# Este sistema describe un movimiento oscilatorio simple y puede resolverse con solve_ivp.

# %%
from scipy.integrate import solve_ivp
import numpy as np
import matplotlib.pyplot as plt

# Definimos el sistema de ecuaciones como una función
def sistema(t, Y):
    y1, y2 = Y  # Desempaquetamos las variables
    dy1_dt = y2
    dy2_dt = -y1
    return [dy1_dt, dy2_dt]

# Condiciones iniciales y configuración del tiempo
condiciones_iniciales = [1, 0]  # y1(0) = 1, y2(0) = 0
t_span = (0, 10)  # Intervalo de tiempo
t_eval = np.linspace(0, 10, 100)  # Puntos de evaluación en el tiempo

# Resolvemos el sistema
solucion = solve_ivp(sistema, t_span, condiciones_iniciales, t_eval=t_eval)

# Graficamos los resultados
plt.plot(solucion.t, solucion.y[0], label='y1(t)')
plt.plot(solucion.t, solucion.y[1], label='y2(t)')
plt.xlabel('Tiempo t')
plt.ylabel('Valores de y1 y y2')
plt.legend()
plt.title('Solución del Sistema de Ecuaciones Diferenciales Acopladas')
plt.grid()
plt.show()

# %% [markdown]
# #### Explicación de los Pasos Clave ####
# Definición del Sistema: En el ejemplo, la función sistema define las derivadas dy1_dt y dy2_dt en términos de y1 y y2. Estas derivadas representan el sistema acoplado de ecuaciones diferenciales.
#
# Condiciones Iniciales: El vector [1, 0] representa y1(0) = 1 y y2(0) = 0, que son los valores iniciales de y1 y y2 en t = 0.
#
# Intervalo y Evaluación en Tiempo: t_span = (0, 10) indica que queremos resolver el sistema entre t = 0 y t = 10. t_eval define los puntos de tiempo donde se evalúan los valores de y1 y y2 para graficarlos.
#
# Resolución con solve_ivp: La función solve_ivp integra el sistema y devuelve una solución que se almacena en solucion. Las salidas solucion.t y solucion.y contienen los valores de t y las soluciones y1 y y2 en cada punto evaluado.

# %% [markdown]
# ## 2. Visualizacion interactiva de funciones o campos vectoriales usando Plotly o Mayavi ##

# %% [markdown]
# Para visualizar funciones o campos vectoriales en 3D de manera interactiva en Python, Plotly y Mayavi son dos opciones populares que ofrecen herramientas para gráficos 3D interactivos.
#
# #### 1. Plotly para Visualización 3D Interactiva ####
# Plotly es una biblioteca de gráficos interactivos que permite crear visualizaciones en 2D y 3D. Sus gráficos son ideales para visualización en entornos web o Jupyter Notebooks, y soporta gráficos como superficies, campos vectoriales y gráficos de dispersión en 3D.
#
# **Herramientas Necesarias:**
# Para trabajar con Plotly en 3D, necesitarás instalar la biblioteca plotly.
#
# **Ejemplo Superficie 3D con Plotly:**
# Este ejemplo muestra cómo graficar una función z = sin(sqrt(x^2 + y^2)) en 3D usando Plotly. El siguiente código genera una visualización interactiva donde puedes rotar, hacer zoom y explorar la superficie en 3D.

# %%
import plotly.graph_objects as go
import numpy as np

# Creamos una malla de puntos en el plano XY
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

# Creamos la gráfica de superficie
fig = go.Figure(data=[go.Surface(z=Z, x=X, y=Y)])
fig.update_layout(title="Superficie 3D: z = sin(sqrt(x^2 + y^2))", 
                  scene=dict(xaxis_title="X", yaxis_title="Y", zaxis_title="Z"))

# Mostramos la gráfica
fig.show()

# %% [markdown]
# ## 2. Mayavi para Visualización Científica 3D ##
# Mayavi es una biblioteca de Python para visualización científica en 3D, ideal para campos vectoriales y simulaciones científicas. Mayavi está diseñado para gráficos avanzados y requiere una instalación adicional de vtk para manejar gráficos 3D.
#
# **Herramientas Necesarias**
# Para utilizar mayavi debes instalar la propia biblioteca y ademas instalar vtk que es la base de los gráficos 3D en Mayavi:
#
# **Ejemplo: Campo Vectorial 3D con Mayavi**
# Este ejemplo genera un campo vectorial 3D donde las flechas representan la dirección y magnitud del vector en cada punto de la malla. La visualización es interactiva, permitiendo rotar y examinar el campo desde distintos ángulos.

# %%
import mayavi as mlab
import numpy as np

# Definimos una malla 3D
x, y, z = np.mgrid[-5:5:20j, -5:5:20j, -5:5:20j]

# Definimos un campo vectorial
u = -y
v = x
w = np.zeros_like(z)

# Creamos el gráfico de campo vectorial
mlab.quiver3d(x, y, z, u, v, w)
mlab.title("Campo Vectorial 3D")
mlab.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 import mayavi as mlab
#       2 import numpy as np
#       4 # Definimos una malla 3D
#
# ModuleNotFoundError: No module named 'mayavi'

# %% [markdown]
# #### Comparación entre Plotly y Mayavi ####
# **Plotly** es fácil de usar en Jupyter y excelente para gráficos interactivos de superficies y datos en la web. Sin embargo, tiene limitaciones para visualizaciones científicas muy complejas.
#
# **Mayavi** está orientado a visualización científica avanzada y es ideal para campos vectoriales en 3D y simulaciones científicas, pero es más complejo de configurar en Jupyter y menos adecuado para entornos web.

# %% [markdown]
# # Parte 4: Reflexion Final #

# %% [markdown]
# SymPy, NumPy y SciPy son herramientas complementarias en el trabajo matemático en Python, cada una con sus fortalezas en distintos tipos de operaciones. Aquí te doy una visión de las capacidades de cada una para análisis matemático simbólico y numérico, y cuál resulta más poderosa según el contexto.
#
# #### 1. SymPy: Poderosa para Cálculo Simbólico ####
# SymPy se especializa en el cálculo simbólico. Permite trabajar con expresiones algebraicas, derivadas, integrales y límites de forma exacta y sin aproximaciones. SymPy es ideal para problemas teóricos y matemáticos, donde es crucial manipular ecuaciones simbólicamente. En resumen, SymPy es la biblioteca más poderosa para manipulación matemática simbólica, proporcionando soluciones exactas y sin aproximaciones.
#
# **Ejemplos prácticos con SymPy:**
#
# Resolución simbólica de ecuaciones: SymPy puede resolver ecuaciones de forma exacta y representar soluciones en términos algebraicos.

# %%
import sympy as sp
x = sp.symbols('x')
eq = sp.Eq(x**2 - 4, 0)
solution = sp.solve(eq, x)  # Devuelve soluciones exactas [-2, 2]
solution
# Out:
# [-2, 2]

# %% [markdown]
# Derivadas e integrales simbólicas: SymPy permite calcular derivadas e integrales de manera analítica.

# %%
f = x**3 + 2*x + 1
integral_f = sp.integrate(f, x)  # Devuelve x**4/4 + x**2 + x
integral_f
# Out:
# x**4/4 + x**2 + x

# %% [markdown]
# #### NumPy: Poderosa para Cálculo Numérico Rápido ####
# NumPy se centra en el cálculo numérico con arrays y álgebra lineal de manera rápida y eficiente. No soporta cálculos simbólicos, pero es extremadamente rápida para operar en matrices y vectores grandes, siendo ideal para procesamiento de datos y cálculos matemáticos donde solo se requieren valores numéricos. En resumen, NumPy es la mejor opción para cálculos numéricos rápidos y en matrices grandes, siendo esencial en ciencia de datos y aprendizaje automático.
#
# **Ejemplos prácticos con NumPy:**
#
# Operaciones en matrices y álgebra lineal: NumPy permite multiplicación de matrices, cálculo de inversas y determinantes de manera eficiente.

# %%
import numpy as np
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])
product = np.dot(A, B)  # Multiplicación de matrices
product
# Out:
# array([[19, 22],
#        [43, 50]])

# %% [markdown]
# #### SciPy: Amplía NumPy para Cálculos Científicos y Numéricos Complejos ####
# SciPy está construido sobre NumPy y proporciona herramientas avanzadas para resolución de ecuaciones diferenciales, integración numérica, optimización y estadísticas. SciPy no trabaja de forma simbólica, pero es extremadamente útil en problemas de ingeniería, física y matemáticas aplicadas. En resumen, SciPy es la biblioteca más poderosa para cálculo científico avanzado en problemas numéricos complejos, como en modelado físico y optimización.
#
# **Ejemplos prácticos con SciPy:**
#
# Resolución de sistemas de ecuaciones diferenciales: SciPy permite resolver sistemas complejos de ecuaciones diferenciales de forma numérica.

# %%
from scipy.integrate import solve_ivp

def dydt(t, y): return -y
solution = solve_ivp(dydt, [0, 5], [1])  # Resuelve y' = -y con y(0) = 1
display(solution)
# Out:
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  1.000e-01  1.032e+00  1.908e+00  2.787e+00
#              3.667e+00  4.549e+00  5.000e+00]
#         y: [[ 1.000e+00  9.048e-01  3.566e-01  1.486e-01  6.170e-02
#               2.560e-02  1.061e-02  6.756e-03]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 44
#      njev: 0
#       nlu: 0

# %% [markdown]
# Integración y optimización numérica: SciPy facilita el cálculo de integrales definidas y optimización de funciones.

# %%
from scipy.integrate import quad
integral, error = quad(np.sin, 0, np.pi)  # Calcula la integral de sin(x) en [0, π]
display(integral, error)
# Out:
# 2.0
# 2.220446049250313e-14

# %% [markdown]
# #### ¿Cuál es la Más Poderosa? ####
# **La elección depende del tipo de trabajo:**
#
# **SymPy** es la más poderosa para cálculo simbólico y teórico, donde necesitas soluciones exactas.
# **NumPy** es la mejor para cálculo numérico rápido en grandes conjuntos de datos, ideal en procesamiento de datos y machine learning.
# **SciPy** es la más poderosa para modelado científico numérico complejo, especialmente cuando necesitas integrar, optimizar o resolver ecuaciones diferenciales.
# En conclusión, cada una es poderosa en su área, pero SymPy destaca en cálculo simbólico y SciPy en aplicaciones científicas avanzadas.
