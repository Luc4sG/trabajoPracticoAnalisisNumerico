# %% [markdown]
# # Actividades de aplicacion #

# %% [markdown]
# ## Parte 1 ##

# %% [markdown]
# #### Sistema de Ecuaciones Homogeneos ####
# ![DFSH.png](attachment:23f2c313-5c7d-41a9-8009-b03bfe014419.png)

# %% [markdown]
# #### Sistema de Ecuaciones No Homogéneos aplicando Laplace ####
#
# ![SNHL.png](attachment:2a266003-7681-4353-832d-e6730ae5628a.png)
